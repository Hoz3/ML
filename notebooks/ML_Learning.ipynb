# %% [markdown]
# # *ML Project

# %% [markdown]
# ## Load Data

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/dataprofessor/data/refs/heads/master/BostonHousing_train.csv')
df
# Out:
#          crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0     0.35809   0.0   6.20     1  0.507  6.951  88.5  2.8617    8  307
# 1     0.15876   0.0  10.81     0  0.413  5.961  17.5  5.2873    4  305
# 2     0.11329  30.0   4.93     0  0.428  6.897  54.3  6.3361    6  300
# 3     0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311
# 4    25.94060   0.0  18.10     0  0.679  5.304  89.1  1.6475   24  666
# ..        ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 399   0.28392   0.0   7.38     0  0.493  5.708  74.3  4.7211    5  287
# 400   0.08664  45.0   3.44     0  0.437  7.178  26.3  6.4798    5  398
# 401   0.15098   0.0  10.01     0  0.547  6.021  82.6  2.7474    6  432
# 402   0.22927   0.0   6.91     0  0.448  6.030  85.5  5.6894    3  233
# 403   0.13914   0.0   4.05     0  0.510  5.572  88.5  2.5961    5  296
#
#      ptratio       b  lstat  medv
# 0       17.4  391.70   9.71  26.7
# 1       19.2  376.94   9.88  21.7
# 2       16.6  391.25  11.38  22.0
# 3       15.2  395.60  12.43  22.9
# 4       20.2  127.36  26.64  10.4
# ..       ...     ...    ...   ...
# 399     19.6  391.13  11.74  18.5
# 400     15.2  390.49   2.87  36.4
# 401     17.8  394.51  10.30  19.2
# 402     17.9  392.74  18.80  16.6
# 403     16.6  396.90  14.69  23.1
#
# [404 rows x 14 columns]

# %% [markdown]
# ## Data Preperation

# %% [markdown]
# ### Data Seperation as X and Y
# [link text](https://)

# %%
y = df['medv']
y
# Out:
# 0      26.7
# 1      21.7
# 2      22.0
# 3      22.9
# 4      10.4
#        ...
# 399    18.5
# 400    36.4
# 401    19.2
# 402    16.6
# 403    23.1
# Name: medv, Length: 404, dtype: float64

# %%
x= df.drop('medv', axis=1)
x
# Out:
#          crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0     0.35809   0.0   6.20     1  0.507  6.951  88.5  2.8617    8  307
# 1     0.15876   0.0  10.81     0  0.413  5.961  17.5  5.2873    4  305
# 2     0.11329  30.0   4.93     0  0.428  6.897  54.3  6.3361    6  300
# 3     0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311
# 4    25.94060   0.0  18.10     0  0.679  5.304  89.1  1.6475   24  666
# ..        ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 399   0.28392   0.0   7.38     0  0.493  5.708  74.3  4.7211    5  287
# 400   0.08664  45.0   3.44     0  0.437  7.178  26.3  6.4798    5  398
# 401   0.15098   0.0  10.01     0  0.547  6.021  82.6  2.7474    6  432
# 402   0.22927   0.0   6.91     0  0.448  6.030  85.5  5.6894    3  233
# 403   0.13914   0.0   4.05     0  0.510  5.572  88.5  2.5961    5  296
#
#      ptratio       b  lstat
# 0       17.4  391.70   9.71
# 1       19.2  376.94   9.88
# 2       16.6  391.25  11.38
# 3       15.2  395.60  12.43
# 4       20.2  127.36  26.64
# ..       ...     ...    ...
# 399     19.6  391.13  11.74
# 400     15.2  390.49   2.87
# 401     17.8  394.51  10.30
# 402     17.9  392.74  18.80
# 403     16.6  396.90  14.69
#
# [404 rows x 13 columns]

# %% [markdown]
# ### Data Splitting

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2, random_state=100)

# %%
x_train
# Out:
#          crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 351   1.38799   0.0   8.14     0  0.538  5.950  82.0  3.9900    4  307
# 69   15.02340   0.0  18.10     0  0.614  5.304  97.3  2.1007   24  666
# 197   0.03359  75.0   2.95     0  0.428  7.024  15.8  5.4011    3  252
# 307   0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 46    7.36711   0.0  18.10     0  0.679  6.193  78.1  1.9356   24  666
# ..        ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 343   0.77299   0.0   8.14     0  0.538  6.495  94.4  4.4547    4  307
# 359   6.65492   0.0  18.10     0  0.713  6.317  83.0  2.7344   24  666
# 323   0.07886  80.0   4.95     0  0.411  7.148  27.7  5.1167    4  245
# 280   0.02899  40.0   1.25     0  0.429  6.939  34.5  8.7921    1  335
# 8     1.22358   0.0  19.58     0  0.605  6.943  97.4  1.8773    5  403
#
#      ptratio       b  lstat
# 351     21.0  232.60  27.71
# 69      20.2  349.48  24.91
# 197     18.3  395.62   1.98
# 307     21.0  393.45   6.48
# 46      20.2   96.73  21.52
# ..       ...     ...    ...
# 343     21.0  387.94  12.80
# 359     20.2  396.90  13.99
# 323     19.2  396.90   3.56
# 280     19.7  389.85   5.89
# 8       14.7  363.43   4.59
#
# [323 rows x 13 columns]

# %%
x_test
# Out:
#          crim     zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 121   2.15505    0.0  19.58     0  0.871  5.628  100.0  1.5166    5  403
# 355   7.52601    0.0  18.10     0  0.713  6.417   98.3  2.1850   24  666
# 225  67.92080    0.0  18.10     0  0.693  5.683  100.0  1.4254   24  666
# 398   0.21409   22.0   5.86     0  0.431  6.438    8.9  7.3967    7  330
# 129   0.26938    0.0   9.90     0  0.544  6.266   82.8  3.2628    4  304
# ..        ...    ...    ...   ...    ...    ...    ...     ...  ...  ...
# 324   0.01432  100.0   1.32     0  0.411  6.816   40.5  8.3248    5  256
# 287   4.03841    0.0  18.10     0  0.532  6.229   90.7  3.0993   24  666
# 127   0.21161    0.0   8.56     0  0.520  6.137   87.4  2.7147    5  384
# 388   3.56868    0.0  18.10     0  0.580  6.437   75.0  2.8965   24  666
# 269  15.87440    0.0  18.10     0  0.671  6.545   99.1  1.5192   24  666
#
#      ptratio       b  lstat
# 121     14.7  169.27  16.65
# 355     20.2  304.21  19.31
# 225     20.2  384.97  22.98
# 398     19.1  377.07   3.59
# 129     18.4  393.39   7.90
# ..       ...     ...    ...
# 324     15.1  392.90   3.95
# 287     20.2  395.33  12.87
# 127     20.9  394.47  13.44
# 388     20.2  393.37  14.36
# 269     20.2  396.90  21.08
#
# [81 rows x 13 columns]

# %% [markdown]
# ## Model Building

# %% [markdown]
# ### Linear Regression

# %% [markdown]
# ### Training the model

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ###Applying the model to make a prediction

# %%
y_lr_train_pred = lr.predict(x_train)
y_lr_test_pred = lr.predict(x_test)

# %%
print(y_lr_train_pred)
# Out:
# [ 9.65973065 11.53474385 33.9945895  25.40372012 13.98468209  5.47954398
#  36.48477182 25.21349217 26.82800182 16.46098583 16.63592559 18.07067911
#  34.30046769 30.39151437 33.09502334 20.20749189 24.95975398 19.5732912
#  31.45858981 12.13091229 17.97809564 30.38037785 22.1422362  33.57874257
#  28.07790277 14.59733171 27.23914929 27.39711132 24.10385769 18.35601745
#  12.87650202 15.08405196 19.87435465 19.78939838 34.52210821 17.54893903
#  22.53007639 37.65060349 20.26297586 29.83139721 15.28281962 23.842834
#  20.58064798 26.32406586 27.5301823  21.23977829  8.18093691 30.70288589
#  20.78952185 25.53159297 16.16810939 31.62087293 23.54771526 34.87325894
#  29.40686822 21.25177964  8.72865647 18.18828438 29.14567853 16.64171565
#  21.29148266 18.9872181  23.7378828  27.44429365  5.22595715 21.61102169
#  21.42559797 30.19281444 19.72671952 17.98473296 17.1891783  13.15621723
#  19.28300548 18.86849818 33.9897199  22.31126124 33.3784975 ]

# %%
print(y_lr_test_pred)
# Out:
# [17.28989682 16.50161493  7.12141757 25.12050967 25.52494691 29.39791516
#  13.88686932 14.64004375 21.96663618 18.38215531 16.34233072 24.75047256
#  21.39807458 19.42633437 14.83285005  7.01579807 27.87619893 15.83545558
#  35.46241894 15.70086245 22.63391081 20.95285107 40.33072976 36.27483139
#  21.34928642 22.94782672 37.38707335 28.4860874  12.06236725 17.42635778
#  17.91985019 21.36134978 27.94328859 30.85923315 19.45820857 20.33444679
#  28.47900431 16.06711917 29.4443463  17.40163719 29.09396067 14.16935034
#  25.39047371 16.51021391 34.21193278 27.37183755 29.6824096  19.29139625
#   9.57135231 35.85825956 24.4207557  42.39467401 31.27634308 25.98447521
#  21.72629858 22.30048294 29.18200363 28.18055451 39.00538936 21.37014741
#  24.36696149 18.34828431 21.45446338 18.51266822 17.00720951 11.54964454
#  35.13218252 21.35888769 17.89149377 17.32670451 17.75428037 31.5359041
#  26.38239537 22.89237089 36.65441589 15.32472096 33.83305014 22.15269049
#  20.08422412 21.60603042 17.49734073]

# %% [markdown]
# ### Evaluate model performance

# %% [markdown]
# ### Evaluate model performance

# %%
from sklearn.metrics import mean_squared_error, r2_score

lr_train_mse = mean_squared_error(y_train, y_lr_train_pred)
lr_train_r2 = r2_score(y_train, y_lr_train_pred)

lr_test_mse = mean_squared_error(y_test, y_lr_test_pred)
lr_test_r2 = r2_score(y_test, y_lr_test_pred)

# %%
lr_train_mse
# Out:
# 20.0388329970164

# %%
lr_train_r2
# Out:
# 0.7589240946812416

# %%
lr_test_mse
# Out:
# 17.397539964588237

# %%
lr_test_r2
# Out:
# 0.8132449778112021

# %%
lr_results = pd.DataFrame(['Linear regression', lr_train_mse, lr_train_r2, lr_test_mse, lr_test_r2]).transpose()
lr_results.columns = ['Method', 'Training MSE', 'Training R2', 'Test MSE', 'Test R2']

# %%
lr_results
# Out:
#               Method Training MSE Training R2  Test MSE   Test R2
# 0  Linear regression    20.038833    0.758924  17.39754  0.813245

# %% [markdown]
# ## Random Forst

# %% [markdown]
# ### Training the model

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(max_depth=2, random_state=100)
rf.fit(x_train, y_train)
# Out:
# RandomForestRegressor(max_depth=2, random_state=100)

# %% [markdown]
# ### Applying the model to make a prediction

# %%
y_rf_train_pred = rf.predict(x_train)
y_rf_test_pred = rf.predict(x_test)

# %% [markdown]
# ### Evaluate model performance

# %%
from sklearn.metrics import mean_squared_error, r2_score

rf_train_mse = mean_squared_error(y_train, y_rf_train_pred)
rf_train_r2 = r2_score(y_train, y_rf_train_pred)

rf_test_mse = mean_squared_error(y_test, y_rf_test_pred)
rf_test_r2 = r2_score(y_test, y_rf_test_pred)

# %%
rf_results = pd.DataFrame(['Random Forest', rf_train_mse, rf_train_r2, rf_test_mse, rf_test_r2]).transpose()
rf_results.columns = ['Method', 'Training MSE', 'Training R2', 'Test MSE', 'Test R2']
rf_results
# Out:
#           Method Training MSE Training R2   Test MSE   Test R2
# 0  Random Forest    15.469576    0.813894  17.990095  0.806884

# %% [markdown]
# ## Model Comparision

# %%
df_models = pd.concat ([lr_results, rf_results], axis=0)
df_models
# Out:
#               Method Training MSE Training R2   Test MSE   Test R2
# 0  Linear regression    20.038833    0.758924   17.39754  0.813245
# 0      Random Forest    15.469576    0.813894  17.990095  0.806884

# %%
df_models.reset_index(drop=True)
# Out:
#               Method Training MSE Training R2   Test MSE   Test R2
# 0  Linear regression    20.038833    0.758924   17.39754  0.813245
# 1      Random Forest    15.469576    0.813894  17.990095  0.806884

# %% [markdown]
# ## Data Visualisation

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.scatter(x=y_train, y=y_lr_train_pred, alpha=0.3)

z=np.polyfit(y_train, y_lr_train_pred, 1)
p=np.poly1d(z)

plt.plot(y_train, p(y_train), '#F8766D')
plt.ylabel('Predict Logs')
plt.xlabel('Experimental Logs')
# Out:
# Text(0.5, 0, 'Experimental Logs')
